# %%
import pandas as pd
import requests

# %%
df = pd.read_excel('../Hayat/List of Credit and CE Faculty with Linkendin Fields to collect.xlsx', index_col=0)  
df.columns = df.iloc[2]
df = df[3:]
df.head()

givenUrl = df[~df['LINKEDIN_URL'].isna()]


givenUrl.shape
# Out:
# (272, 33)

# %%
list_of_urls = givenUrl['LINKEDIN_URL'].tolist()

# %%
list_of_urls
# Out:
# ['https://www.linkedin.com/in/georgepefanis/',
#  'https://www.linkedin.com/in/borst-barbara-9113295/ ',
#  'https://www.linkedin.com/in/steven-goss-a8963641/',
#  'https://www.linkedin.com/in/chetvanwert/',
#  'https://www.linkedin.com/in/karen-schadow-7743b4a',
#  'https://www.linkedin.com/in/josh-moritz-9449933/',
#  'https://www.linkedin.com/in/diversity',
#  'https://www.linkedin.com/in/kelly-kim-07038513/',
#  'https://www.linkedin.com/in/raymond-smith-911ab96/',
#  'https://www.linkedin.com/in/allangreenberg/',
#  'https://www.linkedin.com/in/kevin-jenkins-0316332a/',
#  'https://www.linkedin.com/in/oapousa/',
#  'https://www.linkedin.com/in/kerry-mack-41b34b4/',
#  'https://www.linkedin.com/in/joannetombrakos/',
#  'https://www.linkedin.com/in/carolyn-kissane-b5458a2/',
#  'https://www.linkedin.com/in/mechthildschmidtfeist',
#  'https://www.linkedin.com/in/merrie-frankel/',
#  'https://www.linkedin.com/in/roxana-dinu-62a77a12/',
#  'http://www.linkedin.com/in/jonbanner',
# ...

# %%
api_endpoint = 'https://nubela.co/proxycurl/api/v2/linkedin'
linkedin_profile_url = 'https://www.linkedin.com/in/mechthildschmidtfeist'
api_key = 'jcUTOZZRJOGPvGXGpJTXRA'
headers = {'Authorization': 'Bearer ' + api_key}

response = requests.get(api_endpoint,
                        params={'url': linkedin_profile_url,'skills': 'include'},
                        headers=headers)
profile_data = response.json()
profile_data
# Out:
# {'public_identifier': 'mechthildschmidtfeist',
#  'profile_pic_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/mechthildschmidtfeist/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20231128%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20231128T164020Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=3100810d06ad97ca7b3eeddebf3a5169e12d903c4000519045bfdb7d33fd6fc9',
#  'background_cover_image_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/mechthildschmidtfeist/cover?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20231128%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20231128T164020Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=1e824ad8e9c8900fd5c2966129964f2fdb5ffcdc228d6f5b8bd2be9bd95ee93e',
#  'first_name': 'Mechthild Schmidt',
#  'last_name': 'Feist',
#  'full_name': 'Mechthild Schmidt Feist',
#  'follower_count': 1056,
# ...

# %%
 profile_data['experiences']
# Out:
# [{'starts_at': {'day': 1, 'month': 1, 'year': 2010},
#   'ends_at': None,
#   'company': 'DAAD Alumni Association, USA',
#   'company_linkedin_profile_url': None,
#   'title': 'Board member, former Board President 2015-2016',
#   'description': 'The US alumni association of the DAAD (German Academic Exchange program) builds long-term, active relationships, in which former scholarship holders become members of the DAAD alumni network.',
#   'location': 'NYC',
#   'logo_url': None},
#  {'starts_at': {'day': 1, 'month': 1, 'year': 2006},
#   'ends_at': None,
#   'company': 'TRANSform',
#   'company_linkedin_profile_url': None,
#   'title': 'Motion Designer and Artist',
# ...

# %%
for experiences in profile_data['experiences']:
    print(experiences['company'] + ": "+ experiences["title"])
# Out:
# DAAD Alumni Association, USA: Board member, former Board President 2015-2016
# TRANSform: Motion Designer and Artist
# Human Impacts Institute: Advisory Board Member
# HouseWorks digital media: Creative Director, Motion Designer
# New York Institute of Technology: Adjunct Assistant Professor
# Editel, NY: Animator, Designer
# Pratt Institute, Graduate Animation: Instructor
# StandBy: Graphic Designer
# Arri studios/Roman Kuhn & Partner: Animator, Art Director (Munich, Germany)
# New York University: Clin. Professor of Digital Communications + Media
# NYC ACM Siggraph: Board member
# HBO Studios: Motion Designer

# %%
profile_data['education']
# Out:
# [{'starts_at': {'day': 1, 'month': 1, 'year': 1978},
#   'ends_at': {'day': 31, 'month': 12, 'year': 1983},
#   'field_of_study': 'Fine Arts (painting and video) - (Master of Fine Arts)',
#   'degree_name': 'Staatsexamen and Meisterschüler Prof Diehl',
#   'school': 'Universität der Künste Berlin',
#   'school_linkedin_profile_url': 'https://www.linkedin.com/school/universit%C3%A4t-der-k%C3%BCnste-berlin/',
#   'description': 'Studied with Wolfgang Petrick and Hans Jürgen Diehl',
#   'logo_url': 'https://media.licdn.com/dms/image/C4E0BAQEHhPTY4xouWw/company-logo_100_100/0/1519907065435?e=2147483647&v=beta&t=Ioo50gZ6J0xTuiRRIp_StYsBM0bI7sXMjgKeH3BHSL0',
#   'grade': None,
#   'activities_and_societies': None},
#  {'starts_at': {'day': 1, 'month': 1, 'year': 1983},
#   'ends_at': {'day': 31, 'month': 12, 'year': 1984},
#   'field_of_study': 'Combined Media',
#   'degree_name': 'MFA',
#   'school': 'Hunter College',
# ...

# %%
for education in profile_data['education']:
    if( (education['degree_name']) is None  or ((education['school']) is None) or ((education['field_of_study']) is None)):
        print(education)
    else:
        print(education['school'] + ": " + education['degree_name'] + " in " + education['field_of_study'])
# Out:
# Universität der Künste Berlin: Staatsexamen and Meisterschüler Prof Diehl in Fine Arts (painting and video) - (Master of Fine Arts)
# Hunter College: MFA in Combined Media
# Freie Universität Berlin: Staatsexamen (Masters degree) in HIstory

# %%
profile_data['accomplishment_publications']
# Out:
# [{'name': '(IM-)MATERIALITÄT UND KOMMUNIKATION',
#   'publisher': 'Hochschule Anhalt, Stiftung Bauhaus Dessau',
#   'published_on': {'day': 1, 'month': 1, 'year': 2011},
# ...

# %%
for publication in profile_data['accomplishment_publications']:
    print(publication['name'], end = " ,\n ")
# Out:
# (IM-)MATERIALITÄT UND KOMMUNIKATION ,

# %%
profile_data['accomplishment_honors_awards']
# Out:
# []

# %%
for award in profile_data['accomplishment_honors_awards']:
    print(award['title']+ ": " + award['issuer'], end = ",")

# %%
profile_data['accomplishment_organisations']
# Out:
# [{'starts_at': {'day': 1, 'month': 1, 'year': 2010},
#   'ends_at': None,
#   'org_name': 'DAAD Alumni Association',
#   'title': 'President, Board member',
#   'description': None}]

# %%
for organization in profile_data['accomplishment_organisations']:
    print(organization['org_name'], end = " ,\n")
# Out:
# DAAD Alumni Association ,

# %%
profile_data['certifications']
# Out:
# []

# %%
for certification in profile_data['certifications']:

    print(certification["authority"] + " : " + certification['name'])

# %%
profile_data['skills']
# Out:
# ['Animation',
#  'Video',
#  'Computer Animation',
#  'Digital Media',
#  'Film',
#  'Motion Graphics',
#  'Graphic Design',
#  'Multimedia',
#  'After Effects',
#  'Art',
#  'Editing',
#  'New Media',
#  'Video Editing',
#  'Photoshop',
#  'Adobe Creative Suite',
#  'Graphics',
#  'Teaching',
#  'Visual Effects',
#  'Broadcast',
#  'Premiere',
#  'Art Direction',
#  'Higher Education',
#  'Compositing',
#  'Typography',
#  'Post Production',
#  'Advertising',
#  'Storyboarding',
#  'Traditional Animation',
#  'Virtual Worlds',
#  'Motion Design',
#  'Digital Art',
#  'Drawing',
#  'Digital Painting',
#  'Media History',
#  'Curriculum Design',
#  'Computer Graphics',
#  'Nonprofits',
#  'Adobe Photoshop']

# %%
for skill in profile_data['skills']:
    print(skill,end = ", \n")
# Out:
# Animation,
# Video,
# Computer Animation,
# Digital Media,
# Film,
# Motion Graphics,
# Graphic Design,
# Multimedia,
# After Effects,
# Art,
# Editing,
# New Media,
# Video Editing,
# Photoshop,
# Adobe Creative Suite,
# Graphics,
# Teaching,
# Visual Effects,
# Broadcast,
# Premiere,
# Art Direction,
# Higher Education,
# Compositing,
# Typography,
# Post Production,
# Advertising,
# Storyboarding,
# Traditional Animation,
# Virtual Worlds,
# Motion Design,
# Digital Art,
# Drawing,
# Digital Painting,
# Media History,
# Curriculum Design,
# Computer Graphics,
# Nonprofits,
# Adobe Photoshop,
